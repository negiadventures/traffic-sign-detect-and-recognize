# %% [markdown]
# # Train Sign Detection Model

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10237, done.
# remote: Total 10237 (delta 0), reused 0 (delta 0), pack-reused 10237
# Receiving objects: 100% (10237/10237), 10.44 MiB | 29.70 MiB/s, done.
# Resolving deltas: 100% (7099/7099), done.

# %%
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.9.0+cu111 _CudaDeviceProperties(name='NVIDIA RTX A4000', major=8, minor=6, total_memory=16117MB, multi_processor_count=48)

# %%
# Move into yolov5 repo
# %cd /common/home/an721/Downloads/yolo_sign/yolov5

# %% [markdown]
# ## NOTE before start training:
# 1. --data should be passed abosolute path to the signs.yaml file which is typically inside dataset directory
# 2. --cfg should be passed abosolute path to the models/yolov5.yaml which is inside the yolov5 repository into which we entered in previous step
# 3. --weights should be passed yolov5s.pt file if running the model for the first time which is in the yolov5 repository and later if you want to continue the model from previous state, you can pass best.pt which is inside --project location in weights directory.
# 4. --project is the directory created for your model inside yolov5 repository

# %%
# Train YOLOv5s for 100 epochs
# !python train.py --img 640 --batch 16 --epochs 100 --data /common/home/an721/Downloads/yolo_sign/dataset/signs.yaml --cfg /common/home/an721/Downloads/yolo_sign/yolov5/models/yolov5s.yaml --weights newsigns/signs5/weights/best.pt --name signs --project newsigns
# Out:
# train: weights=newsigns/signs5/weights/best.pt, cfg=/common/home/an721/Downloads/yolo_sign/yolov5/models/yolov5s.yaml, data=/common/home/an721/Downloads/yolo_sign/dataset/signs.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=newsigns, name=signs, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Total 8 (delta 6), reused 6 (delta 6), pack-reused 2
# Unpacking objects: 100% (8/8), 3.45 KiB | 186.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
# ...

# %% [markdown]
# # Testing the Model using a video file

# %%
# !python detect.py --weights best.pt --source 3.mp4
# Out:
# detect: weights=['best.pt'], source=3.mp4, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# YOLOv5 🚀 v6.0-102-gf17c86b torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2858) /content/signs/yolov5/3.mp4: 384x640 Done. (0.030s)
# video 1/1 (2/2858) /content/signs/yolov5/3.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/2858) /content/signs/yolov5/3.mp4: 384x640 Done. (0.027s)
# ...
